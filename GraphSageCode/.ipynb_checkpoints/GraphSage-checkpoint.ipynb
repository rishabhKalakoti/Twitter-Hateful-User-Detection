# %%
import torch
import torch_geometric
from torch_geometric.data import Data, Dataset, InMemoryDataset, NeighborSampler
from torch_geometric.nn import SAGEConv, GATConv
from torch import nn
import numpy as np
from data_preprocess_gnn import construct_dataset, get_labeled_index
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, confusion_matrix, recall_score, f1_score, auc, accuracy_score, precision_score
import torch.nn.functional as F
import random
from torch.nn import init
import argparse
import easydict

# %%
class FullySupervisedGraphSageModel(nn.Module):
    def __init__(self, num_features):
        super(FullySupervisedGraphSageModel, self).__init__()
        self.conv_layers = nn.ModuleList()
        self.conv_layers.append(SAGEConv(num_features, 256))
        #self.conv_layers.append(SAGEConv(256, 256))
        self.classify_layer = nn.Linear(256, 3)
        init.xavier_uniform_(self.classify_layer.weight)
        init.xavier_uniform_(self.conv_layers[0].weight)

    def forward(self, x, data_flow):
        data = data_flow[0]
        x = x[data.n_id]
        x = self.conv_layers[0](x, data.edge_index, size=data.size)
        # data = data_flow[1]
        # x = self.conv_layers[1](x, data.edge_index, size=data.size)
        scores = self.classify_layer(x)
        return F.log_softmax(scores, dim=1)

# %%
class FullySupervisedGATModel(nn.Module):
    def __init__(self, num_features):
        super(FullySupervisedGATModel, self).__init__()
        self.conv_layers = nn.ModuleList()
        self.conv_layers.append(GATConv(num_features, 256))
        #self.conv_layers.append(SAGEConv(256, 256))
        self.classify_layer = nn.Linear(256, 3)
        init.xavier_uniform_(self.classify_layer.weight)
        init.xavier_uniform_(self.conv_layers[0].weight)


    def forward(self, x, data_flow):
        block = data_flow[0]
        x = x[block.n_id]
        x = self.conv_layers[0]((x, x[block.res_n_id].squeeze()), block.edge_index, size=block.size)
        # data = data_flow[1]
        # x = self.conv_layers[1](x, data.edge_index, size=data.size)
        scores = self.classify_layer(x)
        return F.log_softmax(scores, dim=1)

# %%
def train(loader, data, model, optimizer):
    model.train()
    total_loss = 0
    for data_flow in loader(data.train_mask):
        optimizer.zero_grad()
        out = model(data.x, data_flow)
        loss = F.nll_loss(out, data.y[data_flow.n_id], weight=torch.FloatTensor([1, 0 , 10]))
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data_flow.batch_size
    return total_loss / (data.train_mask==True).sum().item()

def test(loader, data, model, mask):
    model.eval()
    y_pred = []
    y_true = []
    correct = 0
    for data_flow in loader(mask):
        pred = model(data.x, data_flow).max(1)[1]
        correct += pred.eq(data.y[data_flow.n_id]).sum().item()
        y_pred.extend([1 if v == 2 else 0 for v in pred])
        y_true.extend([1 if v == 2 else 0 for v in data.y[data_flow.n_id]])
    return correct / (mask==True).sum().item(), y_pred, y_true

# %%
if __name__ == "__main__":
    #process & create the dataset files
#     parser = argparse.ArgumentParser()

#     # system
#     parser.add_argument("--feature", type=str, default="all", help="glove | all")
#     #no use of user_type for now
#     parser.add_argument("--user_type", type=str, default="hate", help="hate | suspend")
#     parser.add_argument("--model_type", type=str, default="sage", help="sage | gat")
#     parser.add_argument("--epoch", type=int, default=201)
#     args = parser.parse_args()
    
    args = easydict.EasyDict({
        "feature": "all",
        "model_type": "sage",
        "epoch" : 201,
        "user_type": "hate"
    })
    assert(args.feature in ['glove', 'all'])
    assert(args.user_type in ['hate', 'suspend'])
    assert(args.model_type in ['sage', 'gat'])
    print("====information of experiment====")
    print("FEATURE: ", args.feature, "classification_type:", args.user_type, "MODEL:", args.model_type)
    print("====end information of experiment====")
    dataset = construct_dataset(args.feature)
    model_type = args.model_type
    hate_index, normal_index = get_labeled_index(feature_type=args.feature)
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    y_all = [2] * len(hate_index)
    y_normal = [0] * len(normal_index)
    y_all.extend(y_normal)
    all_index = []
    all_index.extend(hate_index)
    all_index.extend(normal_index)
    recall_test = []
    accuracy_test = []
    fscore_test = []
    precision_test = []
    all_index = np.array(all_index)
    trail = 0
    for train_i, test_i in skf.split(all_index, y_all):
        print("========begin trail {:01d}===========".format(trail))
        all_train_index = all_index[train_i]
        test_index = all_index[test_i]
        data = dataset[0]
        data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        data.train_mask[all_train_index] = 1
        data.test_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
        data.test_mask[test_index] = 1
        loader = NeighborSampler(data, size=[25], num_hops=1, batch_size=128, shuffle=True, add_self_loops=True)
        if model_type == 'sage':
            model = FullySupervisedGraphSageModel(data.num_features)
        else:
            model = FullySupervisedGATModel(data.num_features)
        #optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-3)
        optimizer = torch.optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.01)
        #loader = DataLoader(dataset, batch_size=args.batch_size, shuffle=True)
        for epoch in range(args.epoch):
            loss = train(loader, data, model, optimizer)
            #test_acc = test(loader, data, model, data.test_mask)
            print('Trail: {:01d}, Epoch: {:02d}, Loss: {:.4f}'.format(trail, epoch, loss))
            if (epoch % 50 == 0):                
                test_acc, y_pred, y_true = test(loader, data, model, data.test_mask)
                fscore = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
                recall = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
                precision = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
                print(confusion_matrix(y_true, y_pred))
                print("Fscore:",fscore, "Recall:", recall, "Precision:", precision, "Test:", test_acc)
        model.eval()
        y_pred = []
        y_true = []
        correct = 0
        for data_flow in loader(data.test_mask):
            pred = model(data.x, data_flow).max(1)[1]
            correct += pred.eq(data.y[data_flow.n_id]).sum().item()
            y_pred.extend([1 if v == 2 else 0 for v in pred])
            y_true.extend([1 if v == 2 else 0 for v in data.y[data_flow.n_id]])
        test_acc = correct / (data.test_mask == True).sum().item()
        fscore = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
        recall = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
        precision = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
        accuracy_test.append(test_acc)
        recall_test.append(recall)
        fscore_test.append(fscore)
        precision_test.append(precision)
        trail+=1
        print("========end this trail==========")
    accuracy_test = np.array(accuracy_test)
    recall_test = np.array(recall_test)
    fscore_test = np.array(fscore_test)
    precision_test = np.array(precision_test)
    print("avg Accuracy   %0.4f +-  %0.4f" % (accuracy_test.mean(), accuracy_test.std()))
    print("avg Recall    %0.4f +-  %0.4f" % (recall_test.mean(), recall_test.std()))
    print("avg Precision    %0.4f +-  %0.4f" % (precision_test.mean(), precision_test.std()))
    print("avg Fscore    %0.4f +-  %0.4f" % (fscore_test.mean(), fscore_test.std()))
# Out:
# ====information of experiment====
# FEATURE:  all classification_type: hate MODEL: sage
# ====end information of experiment====
# ========begin trail 0===========
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 00, Loss: 0.7313
# [[668 218]
#  [ 36  73]]
# Fscore: 0.365 Recall: 0.6697247706422018 Precision: 0.2508591065292096 Test: 0.6954773869346733
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 01, Loss: 0.5446
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 02, Loss: 0.4961
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 03, Loss: 0.4725
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 04, Loss: 0.4555
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 05, Loss: 0.4362
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 06, Loss: 0.4344
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 07, Loss: 0.4191
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 08, Loss: 0.4209
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 09, Loss: 0.4173
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 10, Loss: 0.4045
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 11, Loss: 0.4027
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 12, Loss: 0.3999
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 13, Loss: 0.3931
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 14, Loss: 0.3966
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 15, Loss: 0.3929
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 16, Loss: 0.3952
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 17, Loss: 0.3875
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 18, Loss: 0.3856
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 19, Loss: 0.3845
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 20, Loss: 0.3768
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 21, Loss: 0.3746
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 22, Loss: 0.3809
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 23, Loss: 0.3783
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 24, Loss: 0.3716
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 25, Loss: 0.3794
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 26, Loss: 0.3746
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 27, Loss: 0.3669
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 28, Loss: 0.3710
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 29, Loss: 0.3619
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 30, Loss: 0.3637
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 31, Loss: 0.3651
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 32, Loss: 0.3840
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 33, Loss: 0.3655
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 34, Loss: 0.3640
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 35, Loss: 0.3709
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 36, Loss: 0.3627
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 37, Loss: 0.3601
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 38, Loss: 0.3753
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 39, Loss: 0.3609
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 40, Loss: 0.3559
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 41, Loss: 0.3576
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 42, Loss: 0.3595
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 43, Loss: 0.3579
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 44, Loss: 0.3523
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 45, Loss: 0.3538
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 46, Loss: 0.3515
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 47, Loss: 0.3471
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 48, Loss: 0.3554
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 49, Loss: 0.3570
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 50, Loss: 0.3494
# [[774 112]
#  [ 24  85]]
# Fscore: 0.5555555555555556 Recall: 0.7798165137614679 Precision: 0.43147208121827413 Test: 0.8633165829145729
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 51, Loss: 0.3468
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 52, Loss: 0.3509
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 53, Loss: 0.3518
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 54, Loss: 0.3501
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 55, Loss: 0.3479
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 56, Loss: 0.3402
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 57, Loss: 0.3472
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 58, Loss: 0.3504
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 59, Loss: 0.3585
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 60, Loss: 0.3444
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 61, Loss: 0.3430
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 62, Loss: 0.3420
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 63, Loss: 0.3453
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 64, Loss: 0.3418
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 65, Loss: 0.3458
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 66, Loss: 0.3425
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 67, Loss: 0.3403
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 68, Loss: 0.3368
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 69, Loss: 0.3425
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 70, Loss: 0.3389
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 71, Loss: 0.3502
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 72, Loss: 0.3385
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 73, Loss: 0.3477
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 74, Loss: 0.3419
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 75, Loss: 0.3377
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 76, Loss: 0.3398
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 77, Loss: 0.3434
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 78, Loss: 0.3377
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 79, Loss: 0.3587
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 80, Loss: 0.3383
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 81, Loss: 0.3363
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 82, Loss: 0.3449
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 83, Loss: 0.3357
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 84, Loss: 0.3371
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 85, Loss: 0.3333
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 86, Loss: 0.3350
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 87, Loss: 0.3374
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 88, Loss: 0.3390
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 89, Loss: 0.3382
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 90, Loss: 0.3307
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 91, Loss: 0.3313
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 92, Loss: 0.3350
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 93, Loss: 0.3312
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 94, Loss: 0.3367
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 95, Loss: 0.3284
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 96, Loss: 0.3558
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 97, Loss: 0.3347
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 98, Loss: 0.3326
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 99, Loss: 0.3314
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 100, Loss: 0.3318
# [[781 105]
#  [ 25  84]]
# Fscore: 0.5637583892617449 Recall: 0.7706422018348624 Precision: 0.4444444444444444 Test: 0.8693467336683417
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 101, Loss: 0.3315
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 102, Loss: 0.3305
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 103, Loss: 0.3375
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 104, Loss: 0.3308
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 105, Loss: 0.3222
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 106, Loss: 0.3287
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 107, Loss: 0.3423
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 108, Loss: 0.3281
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 109, Loss: 0.3259
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 110, Loss: 0.3312
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 111, Loss: 0.3255
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 112, Loss: 0.3287
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 113, Loss: 0.3273
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 114, Loss: 0.3275
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 115, Loss: 0.3283
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 116, Loss: 0.3256
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 117, Loss: 0.3301
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 118, Loss: 0.3306
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 119, Loss: 0.3227
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 120, Loss: 0.3280
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 121, Loss: 0.3431
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 122, Loss: 0.3284
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 123, Loss: 0.3331
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 124, Loss: 0.3315
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 125, Loss: 0.3212
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 126, Loss: 0.3218
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 127, Loss: 0.3277
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 128, Loss: 0.3304
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 129, Loss: 0.3257
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 130, Loss: 0.3256
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 131, Loss: 0.3222
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 132, Loss: 0.3287
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 133, Loss: 0.3230
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 134, Loss: 0.3214
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 135, Loss: 0.3258
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 136, Loss: 0.3226
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 137, Loss: 0.3217
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 138, Loss: 0.3202
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 139, Loss: 0.3236
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 140, Loss: 0.3301
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 141, Loss: 0.3245
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 142, Loss: 0.3359
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 143, Loss: 0.3208
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 144, Loss: 0.3207
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 145, Loss: 0.3254
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 146, Loss: 0.3281
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 147, Loss: 0.3206
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 148, Loss: 0.3157
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 149, Loss: 0.3793
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 150, Loss: 0.3258
# [[805  81]
#  [ 29  80]]
# Fscore: 0.5925925925925926 Recall: 0.7339449541284404 Precision: 0.4968944099378882 Test: 0.8894472361809045
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 151, Loss: 0.3253
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 152, Loss: 0.3245
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 153, Loss: 0.3215
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 154, Loss: 0.3262
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 155, Loss: 0.3201
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 156, Loss: 0.3152
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 157, Loss: 0.3252
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 158, Loss: 0.3155
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 159, Loss: 0.3225
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 160, Loss: 0.3234
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 161, Loss: 0.3201
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 162, Loss: 0.3221
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 163, Loss: 0.3196
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 164, Loss: 0.3208
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 165, Loss: 0.3169
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 166, Loss: 0.3164
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 167, Loss: 0.3191
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 168, Loss: 0.3235
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 169, Loss: 0.3126
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 170, Loss: 0.3188
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 171, Loss: 0.3328
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 172, Loss: 0.3223
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 173, Loss: 0.3173
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 174, Loss: 0.3207
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 175, Loss: 0.3220
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 176, Loss: 0.3202
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 177, Loss: 0.3157
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 178, Loss: 0.3346
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 179, Loss: 0.3359
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 180, Loss: 0.3163
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 181, Loss: 0.3189
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 182, Loss: 0.3157
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 183, Loss: 0.3172
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 184, Loss: 0.3112
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 185, Loss: 0.3235
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 186, Loss: 0.3126
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 187, Loss: 0.3121
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 188, Loss: 0.3162
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 189, Loss: 0.3152
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 190, Loss: 0.3153
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 191, Loss: 0.3112
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 192, Loss: 0.3153
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 193, Loss: 0.3181
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 194, Loss: 0.3246
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 195, Loss: 0.3166
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 196, Loss: 0.3175
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 197, Loss: 0.3137
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 198, Loss: 0.3470
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 199, Loss: 0.3140
# tensor([ True, False, False,  ..., False, False,  True], dtype=torch.bool)
# Trail: 0, Epoch: 200, Loss: 0.3197
# [[751 135]
#  [ 23  86]]
# Fscore: 0.5212121212121212 Recall: 0.7889908256880734 Precision: 0.3891402714932127 Test: 0.8412060301507538
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-40-292af426a495> in <module>
#      76             y_pred.extend([1 if v == 2 else 0 for v in pred])
#      77             y_true.extend([1 if v == 2 else 0 for v in data.y[data_flow.n_id]])
# ---> 78         test_acc = correct / data.test_mask.sum().item()
#      79         fscore = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
#      80         recall = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
#
# RuntimeError: "sum_cpu" not implemented for 'Bool'
